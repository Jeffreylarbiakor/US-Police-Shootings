# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pp
import seaborn as sns

# %%
data=pd.read_csv('Downloads\shootings.csv')
data
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
data.head(20)
# Out:
#     id                              name        date   manner_of_death  \
# 0    3                        Tim Elliot  2015-01-02              shot
# 1    4                  Lewis Lee Lembke  2015-01-02              shot
# 2    5                John Paul Quintero  2015-01-03  shot and Tasered
# 3    8                   Matthew Hoffman  2015-01-04              shot
# 4    9                 Michael Rodriguez  2015-01-04              shot
# 5   11                 Kenneth Joe Brown  2015-01-04              shot
# 6   13               Kenneth Arnold Buck  2015-01-05              shot
# 7   15                     Brock Nichols  2015-01-06              shot
# 8   16                     Autumn Steele  2015-01-06              shot
# 9   17                   Leslie Sapp III  2015-01-06              shot
# 10  19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11  21                         Ron Sneed  2015-01-07              shot
# ...

# %%
data.tail(20)
# Out:
#         id                   name        date manner_of_death    armed   age  \
# 4875  5867      Ryan Emblem Moore  2020-06-01            shot  unknown  36.0
# 4876  5896        Sean Monterrosa  2020-06-02            shot   hammer  22.0
# 4877  5897         Tyquarn Graves  2020-06-02            shot      gun  33.0
# 4878  5898          Mary Lawrence  2020-06-03            shot    knife  39.0
# 4879  5902    Gregory W. Hallback  2020-06-03            shot      gun  44.0
# 4880  5904         Eric A. Galvan  2020-06-03            shot      gun  25.0
# 4881  5905  Scott Anderson Hutton  2020-06-03            shot  unknown  36.0
# 4882  5903       Benjamin Ballard  2020-06-05            shot      gun  42.0
# 4883  5899          Kamal Flowers  2020-06-06            shot      gun  24.0
# 4884  5900           Erik Salgado  2020-06-06            shot  unknown  22.0
# 4885  5908           Jarrid Hurst  2020-06-07            shot    knife  35.0
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera', 'arms_category'],
#       dtype='object')

# %%
data.iloc[3450:3460,:]
# Out:
#         id                  name        date manner_of_death       armed  \
# 3450  4045          Jeffrey Sims  2018-09-18            shot       knife
# 3451  4050  Freddie Joe Whitmore  2018-09-20            shot         gun
# 3452  4051  Alexander Carballido  2018-09-20            shot         gun
# 3453  4048          Joshua Works  2018-09-22            shot         gun
# 3454  4053   Nathaniel Sassafras  2018-09-23            shot         gun
# 3455  4047       Ronald W. Leach  2018-09-24            shot  box cutter
# 3456  4054             Ivan Pena  2018-09-24            shot         gun
# 3457  4082         Michael Stout  2018-09-24            shot         gun
# 3458  4055        Dravious Burch  2018-09-25            shot         gun
# 3459  4056           Jaime Lopez  2018-09-25            shot       knife
#
#        age gender      race              city state  signs_of_mental_illness  \
# 3450  37.0      M     White        Marysville    WA                     True
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4895 entries, 0 to 4894
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       4895 non-null   int64
#  1   name                     4895 non-null   object
#  2   date                     4895 non-null   object
#  3   manner_of_death          4895 non-null   object
#  4   armed                    4895 non-null   object
#  5   age                      4895 non-null   float64
#  6   gender                   4895 non-null   object
#  7   race                     4895 non-null   object
#  8   city                     4895 non-null   object
#  9   state                    4895 non-null   object
#  10  signs_of_mental_illness  4895 non-null   bool
#  11  threat_level             4895 non-null   object
#  12  flee                     4895 non-null   object
#  13  body_camera              4895 non-null   bool
# ...

# %%
data.describe()
# Out:
#                 id          age
# count  4895.000000  4895.000000
# mean   2902.148519    36.549750
# std    1683.467910    12.694348
# min       3.000000     6.000000
# 25%    1441.500000    27.000000
# 50%    2847.000000    35.000000
# 75%    4352.500000    45.000000
# max    5925.000000    91.000000

# %%
data['age']=data['age'].astype('int64')
data
# Out:
#         id                name        date   manner_of_death       armed  age  \
# 0        3          Tim Elliot  2015-01-02              shot         gun   53
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun   47
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed   23
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon   32
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun   39
# ...    ...                 ...         ...               ...         ...  ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser   27
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun   23
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed   25
# 4893  5921      William Slyter  2020-06-13              shot         gun   22
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun   31
#
# ...

# %%
data['age'].hist(bins=25)

# %%
sns.countplot(data.gender)
